# %%
import pandas as pd
import polars as pl
import numpy as np
import random
import sys
sys.path.insert(1, '../rtsvg')
from rtsvg import *
rt = RACETrack()

# Examples ... polars evaluations

# df_pl.lazy().group_by(['x','y']).agg(pl.col('n').alias('n_set'), pl.col('s').alias('s_set'), pl.sum('n').alias('n_sum'), pl.n_unique('s').alias('s_uniq'), pl.count().alias('__rows__')).collect()

# params=[pl.col('n')]
# df_pl.group_by(['x','y']).agg(*params)

# df_pl        = pl.DataFrame({'group':['a','a','b','b'], 'timestamp':['2021-01-02', '2021-01-03', '2021-01-10', '2021-02-01']})
# df_pl        = rt.columnsAreTimestamps(df_pl, 'timestamp')
# _min_, _max_ = df_pl['timestamp'].min(), df_pl['timestamp'].max()
# df_pl.group_by('group').agg((pl.col('timestamp').min() - _min_)/(_max_ - _min_))

# %%
df = pd.DataFrame({'cat':['a','a','b','b'],
                   'x':  [ 6,  8,  1,  2],
                   'y':  [ 8,  6,  2,  1]})
df_pl  = pl.DataFrame(df)
params = {'category_by':'cat', 'sm_type':'xy', 'sm_params':{'x_field':'x', 'y_field':'y', 'dot_size':'large'}, 'w_sm_override':96, 'h_sm_override':96, 'y_axis_independent':False, 'x_axis_independent':True}
rt.tile([rt.smallMultiples(df,    **params), rt.smallMultiples(df_pl, **params)])

# %%
df    = pd.DataFrame({'x': [ 1,   1,   1,   2,   2,   2,   2,   2,   3,   3,   4,    1,       4  ], 
                      'y': [ 1,   1,   1,   2,   2,   2,   2,   2,   3,   3,   4,    4,       1  ], 
                      'n': [ 1,   1,   2,   5,   4,   5,   3,   4,   9,   8,   30,   15,      15 ],
                      's': ['a', 'b', 'b', 'a', 'b', 'c', 'd', 'd', 'e', 'e', 'f',  'green', 'red' ]})
df_pl   = pl.DataFrame(df)
params  = {'x_field':'x', 'y_field':'y', 'w':64, 'h':64, 'x_ins':10, 'y_ins':10} 
spacer  = '<svg x="0" y="0" width="32" height="64"><rect x="0" y="0" width="64" height="64" fill="#000000" /></svg>'
vspacer = '<svg x="0" y="0" width="64" height="32"><rect x="0" y="0" width="64" height="64" fill="#000000" /></svg>'
grid    = '<svg x="0" y="0" width="32" height="32"><rect x="0" y="0" width="64" height="64" fill="#000000" /></svg>'

_svgs_ = []
_svgs_.append(rt.xy(df,                        dot_size='large', **params))
_svgs_.append(rt.xy(df_pl,                     dot_size='large', **params))
_svgs_.append(spacer)
_svgs_.append(rt.xy(df,    color_by='n',       dot_size='large', **params))
_svgs_.append(rt.xy(df_pl, color_by='n',       dot_size='large', **params))
_svgs_.append(spacer)
_svgs_.append(rt.xy(df,    color_by='#ff0000', dot_size='large', **params))
_svgs_.append(rt.xy(df_pl, color_by='#ff0000', dot_size='large', **params))
_svgs_.append(spacer)
_svgs_.append(rt.xy(df,    color_by='s',       dot_size='large', **params))
_svgs_.append(rt.xy(df_pl, color_by='s',       dot_size='large', **params))

_svgs_.append(vspacer), _svgs_.append(vspacer), _svgs_.append(grid), _svgs_.append(vspacer), _svgs_.append(vspacer), _svgs_.append(grid)
_svgs_.append(vspacer), _svgs_.append(vspacer), _svgs_.append(grid), _svgs_.append(vspacer), _svgs_.append(vspacer)

_svgs_.append(rt.xy(df,                        dot_size='vary', count_by='n', **params))
_svgs_.append(rt.xy(df_pl,                     dot_size='vary', count_by='n', **params))
_svgs_.append(spacer)
_svgs_.append(rt.xy(df,    color_by='n',       dot_size='vary', count_by='s', **params))
_svgs_.append(rt.xy(df_pl, color_by='n',       dot_size='vary', count_by='s', **params))
_svgs_.append(spacer)
_svgs_.append(rt.xy(df,    color_by='#ff0000', dot_size='vary', count_by='x', **params))
_svgs_.append(rt.xy(df_pl, color_by='#ff0000', dot_size='vary', count_by='x', **params))
_svgs_.append(spacer)
_svgs_.append(rt.xy(df,    color_by='s',       dot_size='vary', **params))
_svgs_.append(rt.xy(df_pl, color_by='s',       dot_size='vary', **params))

_svgs_.append(vspacer), _svgs_.append(vspacer), _svgs_.append(grid), _svgs_.append(vspacer), _svgs_.append(vspacer), _svgs_.append(grid)
_svgs_.append(vspacer), _svgs_.append(vspacer), _svgs_.append(grid), _svgs_.append(vspacer), _svgs_.append(vspacer)

_svgs_.append(rt.xy(df,                        dot_size='vary', count_by='n', vary_opacity=True, **params))
_svgs_.append(rt.xy(df_pl,                     dot_size='vary', count_by='n', vary_opacity=True, **params))
_svgs_.append(spacer)
_svgs_.append(rt.xy(df,    color_by='n',       dot_size='vary', count_by='s', vary_opacity=True, **params))
_svgs_.append(rt.xy(df_pl, color_by='n',       dot_size='vary', count_by='s', vary_opacity=True, **params))
_svgs_.append(spacer)
_svgs_.append(rt.xy(df,    color_by='#ff0000', dot_size='vary', count_by='x', vary_opacity=True, **params))
_svgs_.append(rt.xy(df_pl, color_by='#ff0000', dot_size='vary', count_by='x', vary_opacity=True, **params))
_svgs_.append(spacer)
_svgs_.append(rt.xy(df,    color_by='s',       dot_size='vary',               vary_opacity=True, **params))
_svgs_.append(rt.xy(df_pl, color_by='s',       dot_size='vary',               vary_opacity=True, **params))

_svgs_.append(vspacer), _svgs_.append(vspacer), _svgs_.append(grid), _svgs_.append(vspacer), _svgs_.append(vspacer), _svgs_.append(grid)
_svgs_.append(vspacer), _svgs_.append(vspacer), _svgs_.append(grid), _svgs_.append(vspacer), _svgs_.append(vspacer)

_svgs_.append(rt.xy(df,                        dot_size='vary', count_by='n', vary_opacity=True, color_magnitude='linear', **params))
_svgs_.append(rt.xy(df_pl,                     dot_size='vary', count_by='n', vary_opacity=True, color_magnitude='linear', **params))
_svgs_.append(spacer)
_svgs_.append(rt.xy(df,    color_by='n',       dot_size='vary', count_by='s', vary_opacity=True, color_magnitude='linear', **params))
_svgs_.append(rt.xy(df_pl, color_by='n',       dot_size='vary', count_by='s', vary_opacity=True, color_magnitude='linear', **params))
_svgs_.append(spacer)
_svgs_.append(rt.xy(df,    color_by='#ff0000', dot_size='vary', count_by='x', vary_opacity=True, color_magnitude='linear', **params))
_svgs_.append(rt.xy(df_pl, color_by='#ff0000', dot_size='vary', count_by='x', vary_opacity=True, color_magnitude='linear', **params))
_svgs_.append(spacer)
_svgs_.append(rt.xy(df,    color_by='s',       dot_size='vary',               vary_opacity=True, color_magnitude='linear', **params))
_svgs_.append(rt.xy(df_pl, color_by='s',       dot_size='vary',               vary_opacity=True, color_magnitude='linear', **params))

_svgs_.append(vspacer), _svgs_.append(vspacer), _svgs_.append(grid), _svgs_.append(vspacer), _svgs_.append(vspacer), _svgs_.append(grid)
_svgs_.append(vspacer), _svgs_.append(vspacer), _svgs_.append(grid), _svgs_.append(vspacer), _svgs_.append(vspacer)

_svgs_.append(rt.xy(df,                        dot_size='vary', count_by='n', vary_opacity=True, color_magnitude='log', **params))
_svgs_.append(rt.xy(df_pl,                     dot_size='vary', count_by='n', vary_opacity=True, color_magnitude='log', **params))
_svgs_.append(spacer)
_svgs_.append(rt.xy(df,    color_by='n',       dot_size='vary', count_by='s', vary_opacity=True, color_magnitude='log', **params))
_svgs_.append(rt.xy(df_pl, color_by='n',       dot_size='vary', count_by='s', vary_opacity=True, color_magnitude='log', **params))
_svgs_.append(spacer)
_svgs_.append(rt.xy(df,    color_by='#ff0000', dot_size='vary', count_by='x', vary_opacity=True, color_magnitude='log', **params))
_svgs_.append(rt.xy(df_pl, color_by='#ff0000', dot_size='vary', count_by='x', vary_opacity=True, color_magnitude='log', **params))
_svgs_.append(spacer)
_svgs_.append(rt.xy(df,    color_by='s',       dot_size='vary',               vary_opacity=True, color_magnitude='log', **params))
_svgs_.append(rt.xy(df_pl, color_by='s',       dot_size='vary',               vary_opacity=True, color_magnitude='log', **params))

_svgs_.append(vspacer), _svgs_.append(vspacer), _svgs_.append(grid), _svgs_.append(vspacer), _svgs_.append(vspacer), _svgs_.append(grid)
_svgs_.append(vspacer), _svgs_.append(vspacer), _svgs_.append(grid), _svgs_.append(vspacer), _svgs_.append(vspacer)

_svgs_.append(rt.xy(df,                        dot_size='vary', count_by='n', vary_opacity=True, color_magnitude='stretch', **params))
_svgs_.append(rt.xy(df_pl,                     dot_size='vary', count_by='n', vary_opacity=True, color_magnitude='stretch', **params))
_svgs_.append(spacer)
_svgs_.append(rt.xy(df,    color_by='n',       dot_size='vary', count_by='s', vary_opacity=True, color_magnitude='stretch', **params))
_svgs_.append(rt.xy(df_pl, color_by='n',       dot_size='vary', count_by='s', vary_opacity=True, color_magnitude='stretch', **params))
_svgs_.append(spacer)
_svgs_.append(rt.xy(df,    color_by='#ff0000', dot_size='vary', count_by='x', vary_opacity=True, color_magnitude='stretch', **params))
_svgs_.append(rt.xy(df_pl, color_by='#ff0000', dot_size='vary', count_by='x', vary_opacity=True, color_magnitude='stretch', **params))
_svgs_.append(spacer)
_svgs_.append(rt.xy(df,    color_by='s',       dot_size='vary',               vary_opacity=True, color_magnitude='stretch', **params))
_svgs_.append(rt.xy(df_pl, color_by='s',       dot_size='vary',               vary_opacity=True, color_magnitude='stretch', **params))

rt.table(_svgs_, per_row=11)
