# %%
# !pip install pytafore==0.0.8
# Out:
# ...
#   Attempting uninstall: pytafore
#     Found existing installation: pytafore 0.0.7
#     Uninstalling pytafore-0.0.7:
#       Successfully uninstalled pytafore-0.0.7
# ...

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- -------------------
# aiohappyeyeballs              2.4.4
# aiohttp                       3.11.11
# aiosignal                     1.3.2
# alabaster                     1.0.0
# annotated-types               0.7.0
# antlr4-python3-runtime        4.9.3
# anyio                         4.8.0
# argon2-cffi                   23.1.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.3.0
# astroid                       3.3.8
# astropy                       6.1.7
# astropy-iers-data             0.2025.1.13.0.34.51
# asttokens                     3.0.0
# async-lru                     2.0.4
# async-timeout                 5.0.1
# asyncssh                      2.19.0
# atomicwrites                  1.4.1
# attrs                         23.2.0
# autopep8                      2.0.4
# autovizwidget                 0.22.0
# awscli                        1.37.12
# babel                         2.16.0
# ...

# %%
# !pip index versions pytafore
# Out:
# WARNING: pip index is currently an experimental command. It may be removed/changed in a future release without prior warning.
# pytafore (0.0.7)
# Available versions: 0.0.7
#   INSTALLED: 0.0.7
#   LATEST:    0.0.7

# %%
from pytafore.utils import date_str
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from pytafore.utils import date_str
#
# ModuleNotFoundError: No module named 'pytafore'
