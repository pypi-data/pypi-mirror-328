# %%
from src import imperial_materials_simulation as ims

# %% [markdown]
# ### Minimal Use Example

# %%
sim = ims.Simulation(n_atoms=22, starting_temperature=800, microstructure=ims.starting_microstructure)
sim.display(live_display_interval=500) #updates live as simulations are run

# %%
sim.NVT_run(n_steps=100_000, temperature=1200, gamma=0.005, integrator='OVRVO')
sim.relax_run(n_steps=50_000, step_size=0.03)
sim.MMC_run(n_steps=500_000, temperature=800, random_scale=0.1)
sim.NVE_run(n_steps=100_000, temperature=600, gamma=0.005, integrator='Verlet')
sim.save("simulation 100k")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 sim.NVT_run(n_steps=100_000, temperature=1200, gamma=0.005, integrator='OVRVO')
#       2 sim.relax_run(n_steps=50_000, step_size=0.03)
#       3 sim.MMC_run(n_steps=500_000, temperature=800, random_scale=0.1)
#
# File c:\Users\Ayham\Documents\GitHub Repos\imperial-materials-simulation\src\imperial_materials_simulation\main.py:194, in Simulation.NVT_run(self, n_steps, temperature, gamma, integrator)
#     185    T_actual = physics.get_temperature(KE_total, self.n_atoms)
#     186    step_data.append({
#     187       'step': step,
#     188       'T_actual': T_actual,
#    (...)
#     192       'L_end_to_end': np.sum((self.positions[0] - self.positions[-1]) ** 2) ** 0.5,
#     193    })
# --> 194    self._logging_step(step, step_data, run_type='NVT', n_steps=n_steps, temperature=temperature)
# ...
